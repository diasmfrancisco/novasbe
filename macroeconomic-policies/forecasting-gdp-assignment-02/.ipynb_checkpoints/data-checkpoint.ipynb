# %%
import os
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
pd.set_option('max_colwidth', 100)
pd.set_option('display.max_rows', 20)

# %% [markdown]
# <br>

# %% [markdown]
# # Functions

# %%
def M2Q(df_in):
    d = {"M03":"Q1", "M06":"Q2", "M09":"Q3", "M12":"Q4"}
    df_out = df_in[df_in['TIME'].apply(lambda x: x[-3:] in list(d.keys()))].copy()
    df_out.TIME = df_out['TIME'].apply(lambda x: x[:4]+d[x[-3:]]).copy()
    return(df_out)

def Qp1(df_in):
    d = {"Q1":"Q2", "Q2":"Q3", "Q3":"Q4", "Q4":"Q1"}
    df_out = df_in.copy()
    df_out.TIME = df_out['TIME'].apply(lambda x: str(int(x[:-2])+1)+d[x[-2:]] if x[-1:] == "4" else x[:-2]+d[x[-2:]]).copy()
    return(df_out)

# %% [markdown]
# <br>

# %% [markdown]
# # Data

# %%
path = "./data/csvs/"
# !sed -i "s/://g" ./data/*

# %%
#!head -n 1 data/sts_trtu_q_Label.csv

# %% [markdown]
# >## Quarterly

# %%
# DATASET Construction - quarterly data - index (2015 = 100) (NACE Rev. 2) [ei_isbu_q]
ei_isbu_q = pd.read_csv("./data/ei_isbu_q_1_Data.csv", low_memory=False, usecols=lambda x: x not in ["Flag and Footnotes"]).dropna()
ei_isbu_q_lag = Qp1(ei_isbu_q.copy())

# DATASET Final consumption aggregates [namq_10_fcs]
namq_10_fcs = pd.read_csv("./data/namq_10_fcs_1_Data.csv", low_memory=False, usecols=lambda x: x not in ["Flag and Footnotes"]).dropna()
namq_10_fcs_lag = Qp1(namq_10_fcs.copy())

# DATASET: GDP and main components  (output, expenditure and income) [namq_10_gdp]
namq_10_gdp = pd.read_csv("./data/namq_10_gdp_1_Data.csv", low_memory=False, usecols=lambda x: x not in ["Flag and Footnotes"]).dropna()
namq_10_gdp_lag = Qp1(namq_10_gdp.copy())

# DATASET Building permits - quarterly data [sts_cobp_q]
sts_cobp_q = pd.read_csv("./data/sts_cobp_q_1_Data.csv", low_memory=False, usecols=lambda x: x not in ["Flag and Footnotes"]).dropna()
sts_cobp_q_lag = Qp1(sts_cobp_q.copy())

# DATASET Production in construction - quarterly data [sts_copr_q]
sts_copr_q = pd.read_csv("./data/sts_copr_q_1_Data.csv", low_memory=False, usecols=lambda x: x not in ["Flag and Footnotes"]).dropna()
sts_copr_q_lag = Qp1(sts_copr_q.copy())

# DATASET Production in industry - quarterly data [sts_inpr_q]
sts_inpr_q = pd.read_csv("./data/sts_inpr_q_1_Data.csv", low_memory=False, usecols=lambda x: x not in ["Flag and Footnotes"]).dropna()
sts_inpr_q_lag = Qp1(sts_inpr_q.copy())

# DATASET Turnover in industry, total - quarterly data [sts_intv_q]
sts_intv_q = pd.read_csv("./data/sts_intv_q_1_Data.csv", low_memory=False, usecols=lambda x: x not in ["Flag and Footnotes"]).dropna()
sts_intv_q_lag = Qp1(sts_intv_q.copy())

# DATASET Turnover and volume of sales in wholesale and retail trade - quarterly data [sts_trtu_q]
sts_trtu_q = pd.read_csv("./data/sts_trtu_q_1_Data.csv", low_memory=False, usecols=lambda x: x not in ["Flag and Footnotes"]).dropna()
sts_trtu_q_lag = Qp1(sts_trtu_q.copy())

# %% [markdown]
# >## Monthly

# %%
# DATASET Euro-zone Business Climate Indicator - monthly data [ei_bsci_m_r2]
ei_bsci_m_r2_1 = M2Q(pd.read_csv("./data/ei_bsci_m_r2_1_Data.csv", low_memory=False, usecols=lambda x: x not in ["Flag and Footnotes"]).dropna())

# DATASET Sentiment indicators - monthly data [ei_bssi_m_r2]
ei_bssi_m_r2 = M2Q(pd.read_csv("./data/ei_bssi_m_r2_1_Data.csv", low_memory=False, usecols=lambda x: x not in ["Flag and Footnotes"]).dropna())

# DATASET Effective exchange rates indices - monthly data [ei_mfef_m]
ei_mfef_m = M2Q(pd.read_csv("./data/ei_mfef_m_1_Data.csv", low_memory=False, usecols=lambda x: x not in ["Flag and Footnotes"]).dropna())

# %% [markdown]
# **Dealing with ids:**

# %%
for df in [ei_isbu_q, ei_isbu_q_lag, namq_10_fcs, namq_10_fcs_lag, namq_10_gdp, 
           namq_10_gdp_lag, sts_cobp_q, sts_cobp_q_lag, sts_copr_q, sts_copr_q_lag, 
           sts_inpr_q, sts_inpr_q_lag, sts_intv_q, sts_intv_q_lag, sts_trtu_q, 
           sts_trtu_q_lag, ei_isbu_q, ei_isbu_q_lag, namq_10_fcs, namq_10_fcs_lag, 
           namq_10_gdp, namq_10_gdp_lag, sts_cobp_q, sts_cobp_q_lag, sts_copr_q, sts_copr_q_lag, 
           sts_inpr_q, sts_inpr_q_lag, sts_intv_q, sts_intv_q_lag, sts_trtu_q, sts_trtu_q_lag, ei_bsci_m_r2_1, ei_bssi_m_r2, ei_mfef_m]:
    df["ID"] = df["TIME"]+df["GEO"]
    df.Value = df.Value.replace(regex=r'[,]+', value='').astype(np.float)

# %% [markdown]
# ># OECD

# %%
def OECD():
    GEO_LABEL2GEO = dict(zip(namq_10_gdp.GEO_LABEL.values, namq_10_gdp.GEO.values)); GEO_LABEL2GEO["Germany"] = "DE"
    df_in = pd.read_csv("data/KEI_13112018143436794_[v1-oecd].csv")
    df_in["GEO"] = df_in.Country.map(GEO_LABEL2GEO)
    df_in = df_in[df_in.GEO.notnull()]
    df_in["ID"] = df_in.TIME.str[:4]+df_in.TIME.str[-2:]+df_in.GEO
    return(df_in)

# %%
OECD = OECD()

# %% [markdown]
# <br>

# %% [markdown]
# # $C$

# %% [markdown]
# >## $Cd$

# %%
def Cd(model_variables=[], version=0, all_boolean=False, country_dummies=True):
    df_in = pd.DataFrame(sorted(list(set(namq_10_fcs.ID))), columns=["ID"])
    
    ###########################################################################################
    
    # Chain linked volumes, percentage change compared to same period in previous year
    var = "CLV_PCH_SM"
    selec = namq_10_fcs[(namq_10_fcs.NA_ITEM=="P311_S14")&(namq_10_fcs.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", var]
    df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Chain linked volumes, percentage change on previous period
    var = "CLV_PCH_PRE"
    if var in model_variables or all_boolean:
        selec = namq_10_fcs_lag[(namq_10_fcs_lag.NA_ITEM=="P311_S14")&(namq_10_fcs_lag.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Business Climate Indicator
    var = "BS-BCI"
    if var in model_variables or all_boolean:
        dic_BCI = dict(zip(ei_bsci_m_r2_1.TIME.values, ei_bsci_m_r2_1.Value.values))
        df_in[var] = df_in.ID.str[:-2].map(dic_BCI)
    
    # Retail Confidence Indicator
    var = "BS-RCI-BAL"
    if var in model_variables or all_boolean:
        selec = ei_bssi_m_r2[ei_bssi_m_r2.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
        
    # Services Confidence Indicator
    var = "BS-SCI-BAL"
    if var in model_variables or all_boolean:
        selec = ei_bssi_m_r2[ei_bssi_m_r2.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Consumer Confidence Indicator
    var = "BS-CSMCI-BAL"
    if var in model_variables or all_boolean:
        selec = ei_bssi_m_r2[ei_bssi_m_r2.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Production in industry: MIG - Durable Consumer Goods
    var = "MIG_DCOG"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[sts_inpr_q.NACE_R2==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Manufacture of motor vehicles, trailers, semi-trailers and of other transport equipment
    # Checked - UNIT I15
    var = "C29_C30"
    if var in model_variables or all_boolean:
        selec = sts_intv_q[(sts_intv_q.NACE_R2==var)&(sts_intv_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
        
    # Harmonised unemployment rate all persons, s.a.
    var = "LRHUTTTT"
    if var in model_variables or all_boolean:
        selec = OECD[OECD.SUBJECT==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
        
    # Passenger car registrations, s.a.
    var = "SLRTCR03"
    if var in model_variables or all_boolean:
        selec = OECD[OECD.SUBJECT==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    ###########################################################################################
    
    # Dummies
    if country_dummies:
        countries = set(namq_10_fcs.GEO); countries.remove('PT')
        for country in sorted(list(countries)):
            df_in[country] = (df_in.ID.str[-2:] == country).astype(int)
    
    Cd = df_in.dropna().copy(); Cd.set_index("ID", inplace=True)
    Cd = Cd.loc[:, (Cd != 0).any(axis=0)].copy()
    del var, selec, df_in
    
    ###########################################################################################
    
    # Save
    if version != 0:
        Cd.to_csv("./regressions/Cd"+str(version)+".csv")
        
    ###########################################################################################
    
    # Regression
    X = sm.add_constant(Cd.loc[:, Cd.columns != "CLV_PCH_SM"].copy())
    y = Cd.loc[:, "CLV_PCH_SM"].copy()
    results = sm.OLS(y, X).fit()
    print(results.summary())
    
    return(Cd)

# %%
Cd1 = Cd(["BS-RCI-BAL", "BS-SCI-BAL", "BS-CSMCI-BAL"], 1)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             CLV_PCH_SM   R-squared:                       0.381
# Model:                            OLS   Adj. R-squared:                  0.371
# Method:                 Least Squares   F-statistic:                     41.82
# Date:                Wed, 14 Nov 2018   Prob (F-statistic):          1.26e-144
# Time:                        10:10:40   Log-Likelihood:                -5697.7
# No. Observations:                1590   AIC:                         1.144e+04
# Df Residuals:                    1566   BIC:                         1.157e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            5.6867      1.146      4.964      0.000       3.440       7.934
# BS-RCI-BAL       0.2389      0.025      9.414      0.000       0.189       0.289
# BS-SCI-BAL       0.1625      0.021      7.852      0.000       0.122       0.203
# BS-CSMCI-BAL     0.1280      0.030      4.274      0.000       0.069       0.187
# AT              -3.9307      1.462     -2.689      0.007      -6.798      -1.063
# BE              -2.8206      1.393     -2.025      0.043      -5.553      -0.089
# BG               5.7781      1.588      3.638      0.000       2.663       8.893
# CZ              -6.8245      1.532     -4.454      0.000      -9.830      -3.819
# DE              -1.2420      1.469     -0.845      0.398      -4.124       1.640
# DK              -5.4201      2.013     -2.693      0.007      -9.368      -1.472
# EE              -1.2912      1.495     -0.864      0.388      -4.223       1.641
# EL               1.0156      1.565      0.649      0.516      -2.054       4.085
# ES              -1.8301      1.375     -1.331      0.183      -4.527       0.867
# FI              -3.7818      1.638     -2.308      0.021      -6.995      -0.568
# FR               1.8363      1.251      1.467      0.142      -0.618       4.291
# IT              -1.8118      1.370     -1.322      0.186      -4.499       0.876
# LT               7.1920      1.459      4.930      0.000       4.331      10.053
# LV               7.8198      1.460      5.355      0.000       4.956      10.684
# MT              -3.5458      1.925     -1.842      0.066      -7.321       0.230
# NL              -5.9470      1.465     -4.060      0.000      -8.820      -3.074
# PL               4.5611      1.470      3.103      0.002       1.678       7.444
# SE              -5.2203      1.517     -3.441      0.001      -8.196      -2.244
# SI              -3.1885      1.497     -2.130      0.033      -6.124      -0.253
# UK              -0.0994      1.396     -0.071      0.943      -2.838       2.640
# ==============================================================================
# Omnibus:                      295.740   Durbin-Watson:                   1.879
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3953.887
# Skew:                           0.451   Prob(JB):                         0.00
# Kurtosis:                      10.673   Cond. No.                         488.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Cd2 = Cd(["BS-RCI-BAL", "BS-SCI-BAL", "BS-CSMCI-BAL", "SLRTCR03", "C29_C30"], 2)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             CLV_PCH_SM   R-squared:                       0.499
# Model:                            OLS   Adj. R-squared:                  0.489
# Method:                 Least Squares   F-statistic:                     51.95
# Date:                Wed, 14 Nov 2018   Prob (F-statistic):          5.33e-148
# Time:                        07:04:34   Log-Likelihood:                -3873.9
# No. Observations:                1118   AIC:                             7792.
# Df Residuals:                    1096   BIC:                             7902.
# Df Model:                          21
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            5.0236      2.056      2.443      0.015       0.989       9.058
# BS-RCI-BAL       0.3269      0.029     11.438      0.000       0.271       0.383
# BS-SCI-BAL       0.1059      0.023      4.631      0.000       0.061       0.151
# BS-CSMCI-BAL     0.1270      0.035      3.583      0.000       0.057       0.197
# C29_C30         -0.0769      0.012     -6.251      0.000      -0.101      -0.053
# SLRTCR03         0.0744      0.011      6.658      0.000       0.052       0.096
# AT              -2.2496      1.565     -1.437      0.151      -5.321       0.822
# BE              -0.9885      1.416     -0.698      0.485      -3.767       1.790
# DE              -0.3665      1.481     -0.248      0.805      -3.272       2.539
# DK              -3.0039      2.004     -1.499      0.134      -6.937       0.929
# EE              -2.4749      1.482     -1.670      0.095      -5.382       0.432
# EL               1.4950      2.027      0.738      0.461      -2.482       5.472
# ES              -1.2299      1.373     -0.896      0.371      -3.925       1.465
# FI              -2.2114      1.700     -1.300      0.194      -5.548       1.125
# FR               1.7169      1.305      1.316      0.188      -0.843       4.277
# IT              -3.9173      1.321     -2.966      0.003      -6.509      -1.326
# LT               9.5064      1.438      6.612      0.000       6.685      12.328
# LV               7.4148      1.386      5.349      0.000       4.695      10.135
# NL              -5.9424      1.576     -3.771      0.000      -9.035      -2.850
# PL               4.4546      1.390      3.204      0.001       1.727       7.182
# SE              -5.7215      1.650     -3.468      0.001      -8.958      -2.485
# UK               0.1457      1.415      0.103      0.918      -2.631       2.922
# ==============================================================================
# Omnibus:                      215.815   Durbin-Watson:                   1.923
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3515.921
# Skew:                           0.383   Prob(JB):                         0.00
# Kurtosis:                      11.654   Cond. No.                     2.73e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.73e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
f, axes = plt.subplots(1, 2, figsize=(20, 7)); axes = axes.flatten()
sns.heatmap(Cd1.corr(), mask=np.zeros_like(Cd1.corr(), dtype=np.bool),
            cmap=sns.diverging_palette(10, 220, as_cmap=True),square=True, ax=axes[0]);
sns.heatmap(Cd2.corr(), mask=np.zeros_like(Cd2.corr(), dtype=np.bool),
            cmap=sns.diverging_palette(10, 220, as_cmap=True),square=True, ax=axes[1])
plt.tight_layout();

# %%
Cd3 = Cd(["BS-RCI-BAL", "BS-SCI-BAL", "BS-CSMCI-BAL", "SLRTCR03", "C29_C30", "CLV_PCH_PRE"], 3)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             CLV_PCH_SM   R-squared:                       0.608
# Model:                            OLS   Adj. R-squared:                  0.600
# Method:                 Least Squares   F-statistic:                     77.26
# Date:                Wed, 14 Nov 2018   Prob (F-statistic):          8.26e-205
# Time:                        09:01:07   Log-Likelihood:                -3736.3
# No. Observations:                1118   AIC:                             7519.
# Df Residuals:                    1095   BIC:                             7634.
# Df Model:                          22
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            3.1473      1.822      1.727      0.084      -0.428       6.722
# CLV_PCH_PRE      0.9206      0.053     17.482      0.000       0.817       1.024
# BS-RCI-BAL       0.2402      0.026      9.322      0.000       0.190       0.291
# BS-SCI-BAL       0.0783      0.020      3.859      0.000       0.038       0.118
# BS-CSMCI-BAL     0.1011      0.031      3.220      0.001       0.039       0.163
# C29_C30         -0.0622      0.011     -5.696      0.000      -0.084      -0.041
# SLRTCR03         0.0670      0.010      6.772      0.000       0.048       0.086
# AT              -1.7719      1.385     -1.279      0.201      -4.490       0.946
# BE              -0.7242      1.253     -0.578      0.563      -3.182       1.734
# DE              -0.4604      1.310     -0.352      0.725      -3.031       2.110
+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.21e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# >## $Cnd$

# %%
def Cnd(model_variables=[], version=0, all_boolean=False, country_dummies=True):

    df_in = pd.DataFrame(sorted(list(set(namq_10_fcs.ID))), columns=["ID"])
    
    ###########################################################################################
    
    # Chain linked volumes, percentage change compared to same period in previous year
    var = "CLV_PCH_SM"
    selec = namq_10_fcs[(namq_10_fcs.NA_ITEM=="P312N_S14")&(namq_10_fcs.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", var]
    df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Chain linked volumes, percentage change on previous period
    var = "CLV_PCH_PRE"
    if var in model_variables or all_boolean:
        selec = namq_10_fcs_lag[(namq_10_fcs_lag.NA_ITEM=="P312N_S14")&(namq_10_fcs_lag.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Business Climate Indicator
    # Checked - no changes
    var = "BS-BCI"
    if var in model_variables or all_boolean:
        dic_BCI = dict(zip(ei_bsci_m_r2_1.TIME.values, ei_bsci_m_r2_1.Value.values))
        df_in[var] = df_in.ID.str[:-2].map(dic_BCI)
    
    # Retail Confidence Indicator
    # Checked - no changes
    var = "BS-RCI-BAL"
    if var in model_variables or all_boolean:
        selec = ei_bssi_m_r2[ei_bssi_m_r2.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Services Confidence Indicator
    # Checked - no changes
    var = "BS-SCI-BAL"
    if var in model_variables or all_boolean:
        selec = ei_bssi_m_r2[ei_bssi_m_r2.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Consumer Confidence Indicator
    # Checked - no changes
    var = "BS-CSMCI-BAL"
    if var in model_variables or all_boolean:
        selec = ei_bssi_m_r2[ei_bssi_m_r2.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Production in industry: MIG - Non-Durable Consumer Goods
    var = "MIG_NDCOG"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[sts_inpr_q.NACE_R2==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Retail sale of food, beverages and tobacco
    # Checked - UNIT I15
    var = "G47_FOOD"
    if var in model_variables or all_boolean:
        selec = sts_trtu_q[(sts_trtu_q.NACE_R2==var)&(sts_trtu_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Retail sale of non-food products (except fuel)
    # Checked - UNIT I15
    var = "G47_NFOOD_X_G473"
    if var in model_variables or all_boolean:
        selec = sts_trtu_q[(sts_trtu_q.NACE_R2==var)&(sts_trtu_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Retail trade, except of motor vehicles, motorcyles and fuel
    # Checked - UNIT I15
    var = "G47_X_G473"
    if var in model_variables or all_boolean:
        selec = sts_trtu_q[(sts_trtu_q.NACE_R2==var)&(sts_trtu_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Harmonised unemployment rate all persons, s.a.
    var = "LRHUTTTT"
    if var in model_variables or all_boolean:
        selec = OECD[OECD.SUBJECT==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    ###########################################################################################
    
    # Dummies
    if country_dummies:
        countries = set(namq_10_fcs.GEO); countries.remove('PT')
        for country in sorted(list(countries)):
            df_in[country] = (df_in.ID.str[-2:] == country).astype(int)
    
    Cnd = df_in.dropna().copy().set_index("ID")
    Cnd = Cnd.loc[:, (Cnd != 0).any(axis=0)].copy()
    
    del var, selec, df_in
    
    ###########################################################################################
    
    # Save
    if version != 0:
        Cnd.to_csv("./regressions/Cnd"+str(version)+".csv")
    
    ###########################################################################################
    
    # Regression
    X = sm.add_constant(Cnd.loc[:, Cnd.columns != "CLV_PCH_SM"].copy())
    y = Cnd.loc[:, "CLV_PCH_SM"].copy()
    results = sm.OLS(y, X).fit()
    print(results.summary())
    
    return(Cnd)

# %%
Cnd1 = Cnd(["BS-RCI-BAL", "G47_NFOOD_X_G473", "G47_FOOD"], 1)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             CLV_PCH_SM   R-squared:                       0.440
# Model:                            OLS   Adj. R-squared:                  0.432
# Method:                 Least Squares   F-statistic:                     51.86
# Date:                Wed, 14 Nov 2018   Prob (F-statistic):          2.29e-172
# Time:                        10:11:54   Log-Likelihood:                -3518.8
# No. Observations:                1541   AIC:                             7086.
# Df Residuals:                    1517   BIC:                             7214.
# Df Model:                          23
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const
# FR                  -1.5704      0.384     -4.090      0.000      -2.324      -0.817
# IT                  -2.0214      0.385     -5.254      0.000      -2.776      -1.267
# LT                  -0.3559      0.408     -0.872      0.383      -1.157       0.445
# LV                   0.3103      0.394      0.788      0.431      -0.462       1.083
# NL                  -4.0757      0.406    -10.049      0.000      -4.871      -3.280
# PL                  -0.0892      0.412     -0.216      0.829      -0.898       0.720
# SE                  -4.7738      0.427    -11.176      0.000      -5.612      -3.936
# SI                  -3.5822      0.405     -8.843      0.000      -4.377      -2.788
# UK                  -3.2233      0.424     -7.608      0.000      -4.054      -2.392
# ==============================================================================
# Omnibus:                      313.363   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8665.205
# Skew:                          -0.475   Prob(JB):                         0.00
# Kurtosis:                      15.651   Cond. No.                     3.02e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.02e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
Cnd3 = Cnd(["BS-RCI-BAL", "G47_NFOOD_X_G473", "G47_FOOD", "BS-SCI-BAL", "LRHUTTTT", "CLV_PCH_PRE"], 3)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             CLV_PCH_SM   R-squared:                       0.707
# Model:                            OLS   Adj. R-squared:                  0.702
# Method:                 Least Squares   F-statistic:                     133.0
# Date:                Wed, 14 Nov 2018   Prob (F-statistic):          6.21e-318
# Time:                        10:12:01   Log-Likelihood:                -2510.9
# No. Observations:                1292   AIC:                             5070.
# Df Residuals:                    1268   BIC:                             5194.
# Df Model:                          23
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                7.2058      0.816      8.832      0.000       5.605       8.806
# CLV_PCH_PRE          1.4801      0.056     26.531      0.000       1.371       1.590
# BS-RCI-BAL           0.0622      0.005     11.332      0.000       0.051       0.073
# BS-SCI-BAL           0.0235      0.004      5.703      0.000       0.015       0.032
# G47_FOOD            -0.0035      0.009     -0.393      0.694      -0.021       0.014
# G47_NFOOD_X_G473    -0.0303      0.005     -5.933      0.000      -0.040      -0.020
# LRHUTTTT            -0.2285      0.021    -11.049      0.000      -0.269      -0.188
# AT                  -1.9244      0.313     -6.143      0.000      -2.539      -1.310
# BE                  -1.6515      0.303     -5.451      0.000      -2.246      -1.057
# DE                  -1.1738      0.306     -3.835      0.000      -1.774      -0.573
# DK                  -2.3470      0.381     -6.163      0.000      -3.094      -1.600
# EE                  -1.4866      0.339     -4.387      0.000      -2.151      -0.822
# EL                   1.2274      0.363      3.385      0.001       0.516       1.939
# ES                   1.4660      0.326      4.497      0.000       0.826       2.106
# FI                  -1.4277      0.301     -4.746      0.000      -2.018      -0.838
# FR                  -1.0304      0.309     -3.338      0.001      -1.636      -0.425
# IT                  -1.3078      0.310     -4.221      0.000      -1.916      -0.700
# LT                  -0.1672      0.328     -0.510      0.610      -0.810       0.475
# LV                   0.3037      0.316      0.961      0.337      -0.316       0.923
# NL                  -2.6240      0.330     -7.953      0.000      -3.271      -1.977
# PL                  -0.0575      0.331     -0.174      0.862      -0.706       0.591
# SE                  -3.0151      0.349     -8.639      0.000      -3.700      -2.330
# SI                  -2.2694      0.329     -6.904      0.000      -2.914      -1.625
# UK                  -2.1276      0.342     -6.214      0.000      -2.799      -1.456
# ==============================================================================
# Omnibus:                      257.862   Durbin-Watson:                   1.833
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4052.491
# Skew:                          -0.451   Prob(JB):                         0.00
# Kurtosis:                      11.629   Cond. No.                     3.07e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
Cnd_all = Cnd(all_boolean=True)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             CLV_PCH_SM   R-squared:                       0.703
# Model:                            OLS   Adj. R-squared:                  0.703
# Method:                 Least Squares   F-statistic:                     865.8
# Date:                Wed, 14 Nov 2018   Prob (F-statistic):               0.00
# Time:                        07:03:27   Log-Likelihood:                -19457.
# No. Observations:                9889   AIC:                         3.897e+04
# Df Residuals:                    9861   BIC:                         3.917e+04
# Df Model:                          27
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                5.1043      0.316     16.149      0.000       4.485       5.724
# CLV_PCH_PRE          1.5733      0.020     77.819      0.000       1.534       1.613
# BS-BCI               0.0124      0.023      0.535      0.593      -0.033       0.058
# BS-RCI-BAL           0.0502      0.002     23.147      0.000       0.046       0.054
# BS-SCI-BAL           0.0195      0.002     10.412      0.000       0.016       0.023
# BS-CSMCI-BAL         0.0235      0.003      8.900      0.000       0.018       0.029
# MIG_NDCOG           -0.0184      0.002     -7.470      0.000      -0.023      -0.014
# G47_FOOD            -0.0002      0.000     -0.597      0.551      -0.001       0.000
# G47_NFOOD_X_G473    -0.0007      0.000     -1.918      0.055      -0.001    1.51e-05
# G47_X_G473          -0.0005      0.000     -1.313      0.189      -0.001       0.000
# LRHUTTTT            -0.1388      0.007    -19.891      0.000      -0.153      -0.125
# AT                  -1.8340      0.125    -14.650      0.000      -2.079      -1.589
# BE                  -1.6360      0.124    -13.215      0.000      -1.879      -1.393
# DE                  -1.1772      0.119     -9.902      0.000      -1.410      -0.944
# DK                  -2.5300      0.156    -16.183      0.000      -2.836      -2.224
# EE                  -0.8872      0.118     -7.527      0.000      -1.118      -0.656
# EL                   0.6373      0.128      4.977      0.000       0.386       0.888
# ES                   0.4246      0.114      3.731      0.000       0.202       0.648
# FI                  -1.4057      0.133    -10.530      0.000      -1.667      -1.144
# FR                  -0.3749      0.104     -3.599      0.000      -0.579      -0.171
# IT                  -1.1406      0.103    -11.022      0.000      -1.343      -0.938
# LT                   0.1316      0.120      1.096      0.273      -0.104       0.367
# LV                   0.8620      0.109      7.894      0.000       0.648       1.076
# NL                  -2.5051      0.126    -19.958      0.000      -2.751      -2.259
# PL                   0.3039      0.119      2.555      0.011       0.071       0.537
# SE                  -2.1690      0.127    -17.092      0.000      -2.418      -1.920
# SI                  -1.8883      0.118    -15.944      0.000      -2.120      -1.656
# UK                  -1.3475      0.113    -11.924      0.000      -1.569      -1.126
# ==============================================================================
# Omnibus:                     1716.931   Durbin-Watson:                   0.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            27194.727
# Skew:                          -0.352   Prob(JB):                         0.00
# Kurtosis:                      11.093   Cond. No.                     3.29e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# <br>

# %% [markdown]
# # $I$

# %% [markdown]
# >## $Igfcf$

# %%
    model_variables = []; all_boolean= True
    
    df_in = pd.DataFrame(sorted(list(set(namq_10_gdp.ID))), columns=["ID"])
    
    ###########################################################################################
    
    # Chain linked volumes, percentage change compared to same period in previous year
    var = "CLV_PCH_SM"
    selec = namq_10_gdp[(namq_10_gdp.NA_ITEM=="P51G")&(namq_10_gdp.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", var]
    df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    ## Chain linked volumes, percentage change on previous period
    var = "CLV_PCH_PRE"
    if var in model_variables or all_boolean:
        selec = namq_10_gdp_lag[(namq_10_gdp_lag.NA_ITEM=="P51G")&(namq_10_gdp_lag.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Business Climate Indicator
    var = "BS-BCI"
    if var in model_variables or all_boolean:
        dic_BCI = dict(zip(ei_bsci_m_r2_1.TIME.values, ei_bsci_m_r2_1.Value.values))
        df_in[var] = df_in.ID.str[:-2].map(dic_BCI)
    
    # Industrial Confidence Indicator
    var = "BS-ICI-BAL"
    if var in model_variables or all_boolean:
        selec = ei_bssi_m_r2[ei_bssi_m_r2.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Building permits index - New residential buildings
    # Checked - UNIT I2015
    var = "IS-PEI"
    if var in model_variables or all_boolean:
        selec = ei_isbu_q[(ei_isbu_q.INDIC==var)&(ei_isbu_q.UNIT=="I2015")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Residential buildings, except residences for communities
    # Checked - UNIT I15  
    var = "F_CC11_X_CC113"
    if var in model_variables or all_boolean:
        selec = sts_cobp_q[(sts_cobp_q.NACE_R2==var)&(sts_cobp_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Two- and more dwelling buildings
    # Checked - UNIT I15
    var = "F_CC112"
    if var in model_variables or all_boolean:
        selec = sts_cobp_q[(sts_cobp_q.NACE_R2==var)&(sts_cobp_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Construction confidence indicator
    var = "BS-CCI-BAL"
    if var in model_variables or all_boolean:
        selec = ei_bssi_m_r2[ei_bssi_m_r2.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Volume index of production
    # Checked - UNIT I15
    var = "PROD"
    if var in model_variables or all_boolean:
        selec = sts_copr_q[(sts_copr_q.INDIC_BT==var)&(sts_copr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Production in industry: MIG - energy (except Section E)
    # Checked - UNIT I15
    var = "MIG_NRG_X_E"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[(sts_inpr_q.NACE_R2==var)&(sts_inpr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Production in industry: MIG - capital goods
    # Checked - UNIT I15
    var = "MIG_CAG"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[(sts_inpr_q.NACE_R2==var)&(sts_inpr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Production in industry: Mining and quarrying; manufacturing
    # Checked - UNIT I15
    var = "B_C"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[(sts_inpr_q.NACE_R2==var)&(sts_inpr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Production in industry: Mining and quarrying; manufacturing (except MIG energy)
    # Checked - UNIT I15
    var = "B_C_X_MIG_NRG"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[(sts_inpr_q.NACE_R2==var)&(sts_inpr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Production in industry: Manufacturing
    # Checked - UNIT I15
    var = "C"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[(sts_inpr_q.NACE_R2==var)&(sts_inpr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", "C_prod"]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Production in industry: Electricity, gas, steam and air conditioning supply
    # Checked - UNIT I15
    var = "D"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[(sts_inpr_q.NACE_R2==var)&(sts_inpr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Manufacture of motor vehicles, trailers, semi-trailers and of other transport equipment
    # Checked - UNIT I15
    var = "C29_C30"
    if var in model_variables or all_boolean:
        selec = sts_intv_q[(sts_intv_q.NACE_R2==var)&(sts_intv_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Manufacturing
    # Checked - UNIT I15
    var = "C"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[(sts_inpr_q.NACE_R2==var)&(sts_inpr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    ###########################################################################################

# %%
df_in
# Out:
#             ID  CLV_PCH_SM  CLV_PCH_PRE  BS-BCI  BS-ICI-BAL  IS-PEI  \
# 0     1998Q1UK        11.6          2.9     NaN        -2.6   107.7
# 1     1998Q2UK         7.5          0.5     NaN       -13.7   104.8
# 2     1998Q3UK         5.9          2.2     NaN       -23.8   105.8
# 3     1998Q4UK         6.7          0.2     NaN       -26.4   100.5
# 4     1999Q1FR         7.7          1.4    -0.6        -9.8    84.5
# 5     1999Q1LT        -2.0        -12.4    -0.6       -31.5    19.4
# 6     1999Q1UK         5.3          3.7    -0.6       -27.8   106.8
# 7     1999Q2FR         7.5          2.2    -0.4        -8.4    87.9
# 8     1999Q2LT         3.7         -2.3    -0.4       -21.6    31.1
# 9     1999Q2UK         2.4         -0.8    -0.4       -14.6   104.7
# ...        ...         ...          ...     ...         ...     ...
# 1223  2018Q2EL        -5.4        -28.0     1.4        -1.6   168.1
# 1224  2018Q2ES         7.7          1.1     1.4        -0.5   180.3
# 1225  2018Q2FR         3.3          0.1     1.4         5.8   116.3
# 1226  2018Q2HU        14.5          6.1     1.4        15.4   261.4
# 1227  2018Q2LV        13.1          9.8     1.4         0.8   148.2
# 1228  2018Q2PL         5.4          1.7     1.4        -3.1   135.2
# 1229  2018Q2PT         3.7          0.8     1.4         0.9   239.0
# 1230  2018Q2RO        -1.5         -3.0     1.4         1.0   110.9
# 1231  2018Q2SE         3.9          2.5     1.4        15.1    85.0
# 1232  2018Q2UK        -0.6         -1.0     1.4         5.9   104.0
#
#       F_CC11_X_CC113  F_CC112  BS-CCI-BAL   PROD  MIG_NRG_X_E  MIG_CAG    B_C  \
# 0               95.8     55.7        -8.8   79.1        168.8     89.8  116.0
# 1               92.2     56.2       -11.8   76.1        171.6     88.8  115.8
# 2               92.7     58.6       -14.6   76.7        171.4     89.1  115.2
# 3               88.8     57.4       -15.9   76.9        174.5     89.2  114.8
# 4              102.0     45.5        -9.9   98.3         96.5     95.4  103.6
# 5               25.3     12.9       -54.2   63.7         77.5     32.9   44.4
# 6               95.2     58.7       -13.6   78.3        175.3     89.4  114.9
# 7              106.3     51.5         2.3  100.4         96.3     98.5  104.8
# 8               33.1     27.4       -51.6   62.8         93.7     35.8   50.2
# 9               92.2     59.7       -13.0   77.0        175.2     88.8  115.0
# ...              ...      ...         ...    ...          ...      ...    ...
# 1223           163.3    197.2       -47.8  106.2        105.6    112.7  108.6
# 1224           321.2    268.0        -1.4  104.6         98.6    110.9  107.4
# 1225           115.3    125.4         6.4  102.0         97.9    106.8  103.7
# 1226           245.9    323.6        29.0  117.9         99.0    104.2  110.5
# 1227           174.7    375.4        -0.5  122.8        108.0    123.1  116.1
# 1228           132.0    126.5        -7.3  115.0        105.1    117.5  117.1
# 1229           214.1    370.1        -7.5  100.8        117.3    108.6  102.9
# 1230           136.0    192.4       -12.3   91.8        101.8    137.5  122.1
# 1231            80.2     78.0        23.1  108.4        101.3    118.2  110.2
# 1232           114.4     84.9         0.5  111.6         99.8    111.5  103.4
#
#       B_C_X_MIG_NRG  C_prod      D  C29_C30      C
# 0             100.8   103.3   90.1     64.8  103.3
# 1             100.4   103.0   91.7     65.7  103.0
# 2              99.9   102.4   93.6     64.8  102.4
# 3              99.3   101.8   94.6     64.9  101.8
# 4             102.4   103.3   92.5     69.2  103.3
# 5              39.0    44.0  107.9     36.8   44.0
# 6              99.3   101.8   95.0     67.1  101.8
# 7             103.6   105.0   92.2     69.7  105.0
# 8              38.8    49.6   99.1     36.9   49.6
# 9              99.5   102.0   95.7     66.1  102.0
# ...             ...     ...    ...      ...    ...
# 1223          108.5   109.7  104.6     87.5  109.7
# 1224          107.5   107.5   97.4    115.6  107.5
# 1225          103.9   103.9   98.9    115.1  103.9
# 1226          110.9   110.1   93.9    102.4  110.1
# 1227          116.2   116.1  107.9    140.0  116.1
# 1228          118.2   118.2  106.7    122.3  118.2
# 1229          103.2   102.7  121.4    149.2  102.7
# 1230          122.9   124.0  103.6    154.3  124.0
# 1231          110.0   110.0  100.4    140.7  110.0
# 1232          103.5   103.7   99.0    111.2  103.7
#
# [1233 rows x 18 columns]

# %%
def Igfcf(model_variables=[], version=0, all_boolean=False, country_dummies=True):
    
    df_in = pd.DataFrame(sorted(list(set(namq_10_gdp.ID))), columns=["ID"])
    
    ###########################################################################################
    
    # Chain linked volumes, percentage change compared to same period in previous year
    var = "CLV_PCH_SM"
    selec = namq_10_gdp[(namq_10_gdp.NA_ITEM=="P51G")&(namq_10_gdp.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", var]
    df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    ## Chain linked volumes, percentage change on previous period
    var = "CLV_PCH_PRE"
    if var in model_variables or all_boolean:
        selec = namq_10_gdp_lag[(namq_10_gdp_lag.NA_ITEM=="P51G")&(namq_10_gdp_lag.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Business Climate Indicator
    var = "BS-BCI"
    if var in model_variables or all_boolean:
        dic_BCI = dict(zip(ei_bsci_m_r2_1.TIME.values, ei_bsci_m_r2_1.Value.values))
        df_in[var] = df_in.ID.str[:-2].map(dic_BCI)
    
    # Industrial Confidence Indicator
    var = "BS-ICI-BAL"
    if var in model_variables or all_boolean:
        selec = ei_bssi_m_r2[ei_bssi_m_r2.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Building permits index - New residential buildings
    # Checked - UNIT I2015
    var = "IS-PEI"
    if var in model_variables or all_boolean:
        selec = ei_isbu_q[(ei_isbu_q.INDIC==var)&(ei_isbu_q.UNIT=="I2015")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Residential buildings, except residences for communities
    # Checked - UNIT I15  
    var = "F_CC11_X_CC113"
    if var in model_variables or all_boolean:
        selec = sts_cobp_q[(sts_cobp_q.NACE_R2==var)&(sts_cobp_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Two- and more dwelling buildings
    # Checked - UNIT I15
    var = "F_CC112"
    if var in model_variables or all_boolean:
        selec = sts_cobp_q[(sts_cobp_q.NACE_R2==var)&(sts_cobp_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Construction confidence indicator
    var = "BS-CCI-BAL"
    if var in model_variables or all_boolean:
        selec = ei_bssi_m_r2[ei_bssi_m_r2.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Volume index of production
    # Checked - UNIT I15
    var = "PROD"
    if var in model_variables or all_boolean:
        selec = sts_copr_q[(sts_copr_q.INDIC_BT==var)&(sts_copr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Production in industry: MIG - energy (except Section E)
    # Checked - UNIT I15
    var = "MIG_NRG_X_E"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[(sts_inpr_q.NACE_R2==var)&(sts_inpr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Production in industry: MIG - capital goods
    # Checked - UNIT I15
    var = "MIG_CAG"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[(sts_inpr_q.NACE_R2==var)&(sts_inpr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Production in industry: Mining and quarrying; manufacturing
    # Checked - UNIT I15
    var = "B_C"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[(sts_inpr_q.NACE_R2==var)&(sts_inpr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Production in industry: Mining and quarrying; manufacturing (except MIG energy)
    # Checked - UNIT I15
    var = "B_C_X_MIG_NRG"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[(sts_inpr_q.NACE_R2==var)&(sts_inpr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Production in industry: Manufacturing
    # Checked - UNIT I15
    var = "C"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[(sts_inpr_q.NACE_R2==var)&(sts_inpr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", "C_prod"]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Production in industry: Electricity, gas, steam and air conditioning supply
    # Checked - UNIT I15
    var = "D"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[(sts_inpr_q.NACE_R2==var)&(sts_inpr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Manufacture of motor vehicles, trailers, semi-trailers and of other transport equipment
    # Checked - UNIT I15
    var = "C29_C30"
    if var in model_variables or all_boolean:
        selec = sts_intv_q[(sts_intv_q.NACE_R2==var)&(sts_intv_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    # Manufacturing
    # Checked - UNIT I15
    var = "C"
    if var in model_variables or all_boolean:
        selec = sts_inpr_q[(sts_inpr_q.NACE_R2==var)&(sts_inpr_q.UNIT=="I15")][["ID", "Value"]]; selec.columns = ["ID", var]
        df_in = pd.merge(df_in, selec, on='ID', how="inner")
    
    ###########################################################################################
    
    # Dummies
    if country_dummies:
        countries = set(namq_10_gdp.GEO); countries.remove('PT')
        for country in sorted(list(countries)):
            df_in[country] = (df_in.ID.str[-2:] == country).astype(int)
    
    Igfcf = df_in.dropna().copy().set_index("ID")
    Igfcf = Igfcf.loc[:, (Igfcf != 0).any(axis=0)].copy()
    del var, selec, df_in
    
    ###########################################################################################
    
    # Save
    if version != 0:
        Igfcf.to_csv("./regressions/Igfcf"+str(version)+".csv")
    
    ###########################################################################################
    
    # Regression
    X = sm.add_constant(Igfcf.loc[:, Igfcf.columns != "CLV_PCH_SM"].copy())
    y = Igfcf.loc[:, "CLV_PCH_SM"].copy()
    results = sm.OLS(y, X).fit()
    print(results.summary())

# %%
Igfcf1 = Igfcf(["BS-BCI", "BS-BCI", "B_C_X_MIG_NRG"],1)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             CLV_PCH_SM   R-squared:                       0.185
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     15.40
# Date:                Wed, 14 Nov 2018   Prob (F-statistic
True)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             CLV_PCH_SM   R-squared:                       0.521
# Model:                            OLS   Adj. R-squared:                  0.509
# Method:                 Least Squares   F-statistic:                     40.71
# Date:                Wed, 14 Nov 2018   Prob (F-statistic):          1.11e-166
# Time:                        10:22:28   Log-Likelihood:                -4149.1
# No. Observations:                1229   AIC:                             8364.
# Df Residuals:                    1196   BIC:                             8533.
# Df Model:                          32
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             21.6705      3.183      6.807      0.000      15.425      27.916
# CLV_PCH_PRE        0.5502      0.047     11.758      0.000       0.458       0.642
# BS-BCI             1.7541      0.332      5.279      0.000       1.102       2.406
# BS-ICI-BAL         0.1475      0.039      3.791      0.000       0.071       0.224
# IS-PEI            -0.0119      0.008     -1.516      0.130      -0.027       0.004
# F_CC11_X_CC113     0.0075      0.011      0.669      0.504      -0.014       0.029
# F_CC112            0.0037      0.003      1.456      0.146      -0.001       0.009
# BS-CCI-BAL         0.1856      0.015     12.070      0.000       0.155       0.216
# PROD              -0.0100      0.015     -0.666      0.506      -0.040       0.020
# MIG_NRG_X_E       -0.0530      0.043     -1.230      0.219      -0.138       0.032
# MIG_CAG           -0.0126      0.036     -0.353      0.724      -0.083       0.058
# B_C                0.3524      0.238      1.482      0.138      -0.114       0.819
# B_C_X_MIG_NRG     -0.3277      0.170     -1.928      0.054      -0.661       0.006
# C_prod            -0.0173      0.106     -0.163      0.871      -0.226       0.192
# D                 -0.0291      0.034     -0.853      0.394      -0.096       0.038
# C29_C30           -0.0247      0.015     -1.685      0.092      -0.053       0.004
# C                 -0.0173      0.106     -0.163      0.871      -0.226       0.192
# AT                -4.6969      1.656     -2.836      0.005      -7.947      -1.447
# BE                -2.1288      1.753     -1.214      0.225      -5.568       1.311
# BG                 0.2596      1.621      0.160      0.873      -2.921       3.440
# CZ                -3.3382      1.567     -2.130      0.033      -6.413      -0.263
# DE                -2.8861      1.524     -1.893      0.059      -5.877       0.105
# DK                -2.6403      1.809     -1.460      0.145      -6.189       0.909
# EE                -4.1968      1.680     -2.497      0.013      -7.494      -0.900
# EL                -3.3251      1.776     -1.873      0.061      -6.809       0.159
# ES                -0.1665      1.723     -0.097      0.923      -3.547       3.214
# FR                -4.1861      1.570     -2.667      0.008      -7.265      -1.107
# HU                -2.9616      1.629     -1.818      0.069      -6.159       0.235
# LT                 1.4231      1.770      0.804      0.422      -2.051       4.897
# LV                -1.1787      1.964     -0.600      0.549      -5.032       2.675
# PL                 0.8054      1.615      0.499      0.618      -2.364       3.974
# RO                -0.7354      1.596     -0.461      0.645      -3.866       2.396
# SE                -4.0530      1.648     -2.459      0.014      -7.286      -0.820
# UK                -3.7011      1.653     -2.239      0.025      -6.945      -0.457
# ==============================================================================
# Omnibus:                      187.743   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1625.833
# Skew:                           0.415   Prob(JB):                         0.00
# Kurtosis:                       8.573   Cond. No.                     1.48e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.27e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# <br>

# %% [markdown]
# # $G$

# %% [markdown]
# $$G_t = \textit{Purchases of Goods and Services}_t+ \textit{Wages Public Servants}_t+ \textit{Investment}_t$$

# %%
(2128.4/0.99637)/8656.2-1
# Out:
# -0.7532226335007505

# %%
namq_10_gdp.head(2)
# Out:
#        TIME TIME_LABEL GEO GEO_LABEL        UNIT  \
# 324  1975Q1     1975Q1  FR    France     CP_MEUR
# 333  1975Q1     1975Q1  FR    France  CLV10_MEUR
#
#                                     UNIT_LABEL S_ADJ  \
# 324               Current prices, million euro   SCA
# 333  Chain linked volumes (2010), million euro   SCA
#
#                                S_ADJ_LABEL NA_ITEM  \
# 324  Seasonally and calendar adjusted data    B1GQ
# 333  Seasonally and calendar adjusted data    B1GQ
#
#                                NA_ITEM_LABEL     Value        ID
# 324  Gross domestic product at market prices   67383.3  1975Q1FR
# 333  Gross domestic product at market prices  237727.0  1975Q1FR

# %%
namq_10_gdp[((namq_10_gdp.GEO=="PT")&(namq_10_gdp.NA_ITEM=="P3_S13"))&(namq_10_gdp.UNIT=="CLV10_MEUR")]
# Out:
#           TIME TIME_LABEL GEO GEO_LABEL        UNIT  \
# 110206  1995Q1     1995Q1  PT  Portugal  CLV10_MEUR
# 111574  1995Q2     1995Q2  PT  Portugal  CLV10_MEUR
# 112942  1995Q3     1995Q3  PT  Portugal  CLV10_MEUR
# 114310  1995Q4     1995Q4  PT  Portugal  CLV10_MEUR
# 115678  1996Q1     1996Q1  PT  Portugal  CLV10_MEUR
# 117046  1996Q2     1996Q2  PT  Portugal  CLV10_MEUR
# 118414  1996Q3     1996Q3  PT  Portugal  CLV10_MEUR
# 119782  1996Q4     1996Q4  PT  Portugal  CLV10_MEUR
# 121150  1997Q1     1997Q1  PT  Portugal  CLV10_MEUR
# 122518  1997Q2     1997Q2  PT  Portugal  CLV10_MEUR
# ...        ...        ...  ..       ...         ...
# 225118  2016Q1     2016Q1  PT  Portugal  CLV10_MEUR
# 226486  2016Q2     2016Q2  PT  Portugal  CLV10_MEUR
# 227854  2016Q3     2016Q3  PT  Portugal  CLV10_MEUR
# 229222  2016Q4     2016Q4  PT  Portugal  CLV10_MEUR
# 230590  2017Q1     2017Q1  PT  Portugal  CLV10_MEUR
# 231958  2017Q2     2017Q2  PT  Portugal  CLV10_MEUR
# 233326  2017Q3     2017Q3  PT  Portugal  CLV10_MEUR
# 234694  2017Q4     2017Q4  PT  Portugal  CLV10_MEUR
# 236062  2018Q1     2018Q1  PT  Portugal  CLV10_MEUR
# 237430  2018Q2     2018Q2  PT  Portugal  CLV10_MEUR
#
#                                        UNIT_LABEL S_ADJ  \
# 110206  Chain linked volumes (2010), million euro   SCA
# 111574  Chain linked volumes (2010), million euro   SCA
# 112942  Chain linked volumes (2010), million euro   SCA
# 114310  Chain linked volumes (2010), million euro   SCA
# 115678  Chain linked volumes (2010), million euro   SCA
# 117046  Chain linked volumes (2010), million euro   SCA
# 118414  Chain linked volumes (2010), million euro   SCA
# 119782  Chain linked volumes (2010), million euro   SCA
# 121150  Chain linked volumes (2010), million euro   SCA
# 122518  Chain linked volumes (2010), million euro   SCA
# ...                                           ...   ...
# 225118  Chain linked volumes (2010), million euro   SCA
# 226486  Chain linked volumes (2010), million euro   SCA
# 227854  Chain linked volumes (2010), million euro   SCA
# 229222  Chain linked volumes (2010), million euro   SCA
# 230590  Chain linked volumes (2010), million euro   SCA
# 231958  Chain linked volumes (2010), million euro   SCA
# 233326  Chain linked volumes (2010), million euro   SCA
# 234694  Chain linked volumes (2010), million euro   SCA
# 236062  Chain linked volumes (2010), million euro   SCA
# 237430  Chain linked volumes (2010), million euro   SCA
#
#                                   S_ADJ_LABEL NA_ITEM  \
# 110206  Seasonally and calendar adjusted data  P3_S13
# 111574  Seasonally and calendar adjusted data  P3_S13
# 112942  Seasonally and calendar adjusted data  P3_S13
# 114310  Seasonally and calendar adjusted data  P3_S13
# 115678  Seasonally and calendar adjusted data  P3_S13
# 117046  Seasonally and calendar adjusted data  P3_S13
# 118414  Seasonally and calendar adjusted data  P3_S13
# 119782  Seasonally and calendar adjusted data  P3_S13
# 121150  Seasonally and calendar adjusted data  P3_S13
# 122518  Seasonally and calendar adjusted data  P3_S13
# ...                                       ...     ...
# 225118  Seasonally and calendar adjusted data  P3_S13
# 226486  Seasonally and calendar adjusted data  P3_S13
# 227854  Seasonally and calendar adjusted data  P3_S13
# 229222  Seasonally and calendar adjusted data  P3_S13
# 230590  Seasonally and calendar adjusted data  P3_S13
# 231958  Seasonally and calendar adjusted data  P3_S13
# 233326  Seasonally and calendar adjusted data  P3_S13
# 234694  Seasonally and calendar adjusted data  P3_S13
# 236062  Seasonally and calendar adjusted data  P3_S13
# 237430  Seasonally and calendar adjusted data  P3_S13
#
#                                               NA_ITEM_LABEL   Value        ID
# 110206  Final consumption expenditure of general government  6476.3  1995Q1PT
# 111574  Final consumption expenditure of general government  6546.0  1995Q2PT
# 112942  Final consumption expenditure of general government  6612.1  1995Q3PT
# 114310  Final consumption expenditure of general government  6673.7  1995Q4PT
# 115678  Final consumption expenditure of general government  6725.7  1996Q1PT
# 117046  Final consumption expenditure of general government  6763.0  1996Q2PT
# 118414  Final consumption expenditure of general government  6784.4  1996Q3PT
# 119782  Final consumption expenditure of general government  6799.2  1996Q4PT
# 121150  Final consumption expenditure of general government  6822.3  1997Q1PT
# 122518  Final consumption expenditure of general government  6877.5  1997Q2PT
# ...                                                     ...     ...       ...
# 225118  Final consumption expenditure of general government  8640.4  2016Q1PT
# 226486  Final consumption expenditure of general government  8670.0  2016Q2PT
# 227854  Final consumption expenditure of general government  8607.4  2016Q3PT
# 229222  Final consumption expenditure of general government  8622.5  2016Q4PT
# 230590  Final consumption expenditure of general government  8634.9  2017Q1PT
# 231958  Final consumption expenditure of general government  8644.4  2017Q2PT
# 233326  Final consumption expenditure of general government  8656.2  2017Q3PT
# 234694  Final consumption expenditure of general government  8672.9  2017Q4PT
# 236062  Final consumption expenditure of general government  8694.8  2018Q1PT
# 237430  Final consumption expenditure of general government  8718.1  2018Q2PT
#
# [94 rows x 12 columns]

# %%
namq_10_gdp[["NA_ITEM","NA_ITEM_LABEL"]].drop_duplicates()
# Out:
#        NA_ITEM  \
# 324       B1GQ
# 17461   P3_S13
# 17462      P5G
# 17463     P51G
# 17465      P52
# 17466      P53
# 17467       P6
# 17468       P7
# 27688  P52_P53
#
#                                                              NA_ITEM_LABEL
# 324                                Gross domestic product at market prices
# 17461                  Final consumption expenditure of general government
# 17462                                              Gross capital formation
# 17463                                        Gross fixed capital formation
# 17465                                               Changes in inventories
# 17466                             Acquisitions less disposals of valuables
# 17467                                        Exports of goods and services
# 17468                                        Imports of goods and services
# 27688  Changes in inventories and acquisitions less disposals of valuables

# %%
namq_10_gdp[(namq_10_gdp.UNIT=="CP_MEUR")&(namq_10_gdp.NA_ITEM=="P3_S13")]
# Out:
#           TIME TIME_LABEL GEO       GEO_LABEL     UNIT  \
# 17461   1978Q1     1978Q1  NO          Norway  CP_MEUR
# 18829   1978Q2     1978Q2  NO          Norway  CP_MEUR
# 20197   1978Q3     1978Q3  NO          Norway  CP_MEUR
# 21565   1978Q4     1978Q4  NO          Norway  CP_MEUR
# 22933   1979Q1     1979Q1  NO          Norway  CP_MEUR
# 24301   1979Q2     1979Q2  NO          Norway  CP_MEUR
# 25669   1979Q3     1979Q3  NO          Norway  CP_MEUR
# 27037   1979Q4     1979Q4  NO          Norway  CP_MEUR
# 27685   1980Q1     1980Q1  FR          France  CP_MEUR
# 28405   1980Q1     1980Q1  NO          Norway  CP_MEUR
# ...        ...        ...  ..             ...      ...
# 237493  2018Q2     2018Q2  SI        Slovenia  CP_MEUR
# 237565  2018Q2     2018Q2  FI         Finland  CP_MEUR
# 237601  2018Q2     2018Q2  SE          Sweden  CP_MEUR
# 237637  2018Q2     2018Q2  UK  United Kingdom  CP_MEUR
# 237709  2018Q2     2018Q2  NO          Norway  CP_MEUR
# 237745  2018Q2     2018Q2  CH     Switzerland  CP_MEUR
# 238321  2018Q3     2018Q3  ES           Spain  CP_MEUR
# 238357  2018Q3     2018Q3  FR          France  CP_MEUR
# 238717  2018Q3     2018Q3  AT         Austria  CP_MEUR
# 239005  2018Q3     2018Q3  UK  United Kingdom  CP_MEUR
#
#                           UNIT_LABEL S_ADJ  \
# 17461   Current prices, million euro   SCA
# 18829   Current prices, million euro   SCA
# 20197   Current prices, million euro   SCA
# 21565   Current prices, million euro   SCA
# 22933   Current prices, million euro   SCA
# 24301   Current prices, million euro   SCA
# 25669   Current prices, million euro   SCA
# 27037   Current prices, million euro   SCA
# 27685   Current prices, million euro   SCA
# 28405   Current prices, million euro   SCA
# ...                              ...   ...
# 237493  Current prices, million euro   SCA
# 237565  Current prices, million euro   SCA
# 237601  Current prices, million euro   SCA
# 237637  Current prices, million euro   SCA
# 237709  Current prices, million euro   SCA
# 237745  Current prices, million euro   SCA
# 238321  Current prices, million euro   SCA
# 238357  Current prices, million euro   SCA
# 238717  Current prices, million euro   SCA
# 239005  Current prices, million euro   SCA
#
#                                   S_ADJ_LABEL NA_ITEM  \
# 17461   Seasonally and calendar adjusted data  P3_S13
# 18829   Seasonally and calendar adjusted data  P3_S13
# 20197   Seasonally and calendar adjusted data  P3_S13
# 21565   Seasonally and calendar adjusted data  P3_S13
# 22933   Seasonally and calendar adjusted data  P3_S13
# 24301   Seasonally and calendar adjusted data  P3_S13
# 25669   Seasonally and calendar adjusted data  P3_S13
# 27037   Seasonally and calendar adjusted data  P3_S13
# 27685   Seasonally and calendar adjusted data  P3_S13
# 28405   Seasonally and calendar adjusted data  P3_S13
# ...                                       ...     ...
# 237493  Seasonally and calendar adjusted data  P3_S13
# 237565  Seasonally and calendar adjusted data  P3_S13
# 237601  Seasonally and calendar adjusted data  P3_S13
# 237637  Seasonally and calendar adjusted data  P3_S13
# 237709  Seasonally and calendar adjusted data  P3_S13
# 237745  Seasonally and calendar adjusted data  P3_S13
# 238321  Seasonally and calendar adjusted data  P3_S13
# 238357  Seasonally and calendar adjusted data  P3_S13
# 238717  Seasonally and calendar adjusted data  P3_S13
# 239005  Seasonally and calendar adjusted data  P3_S13
#
#                                               NA_ITEM_LABEL     Value  \
# 17461   Final consumption expenditure of general government    1799.0
# 18829   Final consumption expenditure of general government    1760.5
# 20197   Final consumption expenditure of general government    1801.0
# 21565   Final consumption expenditure of general government    1858.2
# 22933   Final consumption expenditure of general government    1810.9
# 24301   Final consumption expenditure of general government    1871.2
# 25669   Final consumption expenditure of general government    1892.9
# 27037   Final consumption expenditure of general government    1931.9
# 27685   Final consumption expenditure of general government   25124.9
# 28405   Final consumption expenditure of general government    2057.0
# ...                                                     ...       ...
# 237493  Final consumption expenditure of general government    2080.5
# 237565  Final consumption expenditure of general government   13144.0
# 237601  Final consumption expenditure of general government   30223.4
# 237637  Final consumption expenditure of general government  108124.1
# 237709  Final consumption expenditure of general government   21706.5
# 237745  Final consumption expenditure of general government   17374.0
# 238321  Final consumption expenditure of general government   56107.0
# 238357  Final consumption expenditure of general government  137005.0
# 238717  Final consumption expenditure of general government   18720.6
# 239005  Final consumption expenditure of general government  108651.1
#
#               ID
# 17461   1978Q1NO
# 18829   1978Q2NO
# 20197   1978Q3NO
# 21565   1978Q4NO
# 22933   1979Q1NO
# 24301   1979Q2NO
# 25669   1979Q3NO
# 27037   1979Q4NO
# 27685   1980Q1FR
# 28405   1980Q1NO
# ...          ...
# 237493  2018Q2SI
# 237565  2018Q2FI
# 237601  2018Q2SE
# 237637  2018Q2UK
# 237709  2018Q2NO
# 237745  2018Q2CH
# 238321  2018Q3ES
# 238357  2018Q3FR
# 238717  2018Q3AT
# 239005  2018Q3UK
#
# [2918 rows x 12 columns]

# %%
99879.5

# %% [markdown]
# <br>

# %% [markdown]
# # $X$

# %%
df_in = pd.DataFrame(sorted(list(set(namq_10_gdp.ID))), columns=["ID"])

###########################################################################################

# Chain linked volumes, percentage change compared to same period in previous year
var = "CLV_PCH_SM"
selec = namq_10_gdp[(namq_10_gdp.NA_ITEM=="P51G")&(namq_10_gdp.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", var]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

# Chain linked volumes, percentage change on previous period
var = "CLV_PCH_PRE"
selec = namq_10_gdp_lag[(namq_10_gdp_lag.NA_ITEM=="P51G")&(namq_10_gdp_lag.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", var]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

# Economic sentiment indicator
var = "BS-ESI-I"
selec = ei_bssi_m_r2[ei_bssi_m_r2.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

# Consumer confidence indicator
var = "BS-CSMCI-BAL"
selec = ei_bssi_m_r2[ei_bssi_m_r2.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

# Retail confidence indicator
var = "BS-RCI-BAL"
selec = ei_bssi_m_r2[ei_bssi_m_r2.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
df_in = pd.merge(df_in, selec, on='ID', how="inner")


###########################################




###########################################################################################

# Dummies
countries = set(namq_10_gdp.GEO); countries.remove('PT')
for country in sorted(list(countries)):
    df_in[country] = (df_in.ID.str[-2:] == country).astype(int)

Igfcf = df_in.copy().set_index("ID")
Igfcf = Igfcf.loc[:, (Igfcf != 0).any(axis=0)].copy()
del var, selec, df_in

###########################################################################################

# Save
Igfcf.to_csv("./Igfcf.csv")

###########################################################################################

# Regression
X = sm.add_constant(Igfcf.loc[:, Igfcf.columns != "CLV_PCH_SM"].copy())
y = Igfcf.loc[:, "CLV_PCH_SM"].copy()
results = sm.OLS(y, X).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             CLV_PCH_SM   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.271
# Method:                 Least Squares   F-statistic:                     27.17
# Date:                Wed, 14 Nov 2018   Prob (F-statistic):          3.11e-118
# Time:                        03:28:58   Log-Likelihood:                -7485.2
# No. Observations:                1974   AIC:                         1.503e+04
# Df Residuals:                    1945   BIC:                         1.519e+04
# Df Model:                          28
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -43.8957      5.750     -7.635      0.000     -55.172     -32.620
# CLV_PCH_PRE      0.0752      0.023      3.283      0.001       0.030       0.120
# BS-ESI-I         0.4532      0.050      9.116      0.000       0.356       0.551
# BS-CSMCI-BAL     0.0039      0.037      0.104      0.917      -0.069       0.077
# BS-RCI-BAL       0.1863      0.030      6.192      0.000       0.127       0.245
# AT               0.7728      1.799      0.430      0.668      -2.755       4.301
# BE               1.0045      1.716      0.585      0.558      -2.361       4.370
# BG               1.0844      1.855      0.584      0.559      -2.554       4.723
# CY               5.8311      1.785      3.267      0.001       2.331       9.331
# CZ              -3.0524      1.813     -1.683      0.092      -6.608       0.504
# DE               3.1911      1.704      1.873      0.061      -0.150       6.533
# DK              -0.2991      2.525     -0.118      0.906      -5.251       4.653
# EE               4.1210      1.675      2.460      0.014       0.836       7.406
# EL              -0.5019      1.797     -0.279      0.780      -4.025       3.022
# ES               0.9929      1.648      0.603      0.547      -2.238       4.224
# FI               0.2329      2.081      0.112      0.911      -3.848       4.313
# FR               2.1342      1.484      1.438      0.151      -0.777       5.045
# HR              -1.3738      2.058     -0.667      0.505      -5.411       2.663
# HU               2.6695      1.644      1.623      0.105      -0.556       5.895
# IT              -0.2802      1.647     -0.170      0.865      -3.511       2.950
# LT               3.2794      1.746      1.878      0.061      -0.146       6.704
# LV               1.5823      1.753      0.903      0.367      -1.855       5.020
# MT               2.8886      2.351      1.229      0.219      -1.722       7.499
# NL              -0.6833      1.864     -0.367      0.714      -4.339       2.973
# PL               3.7887      1.748      2.167      0.030       0.361       7.217
# RO               3.6523      1.793      2.036      0.042       0.135       7.170
# SE              -1.2471      2.009     -0.621      0.535      -5.188       2.693
# SI              -2.9044      1.739     -1.670      0.095      -6.315       0.506
# UK              -0.7718      1.701     -0.454      0.650      -4.107       2.563
# ==============================================================================
# Omnibus:                     2301.793   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           893196.347
# Skew:                           5.435   Prob(JB):                         0.00
# Kurtosis:                     106.641   Cond. No.                     3.00e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  3e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# <br>

# %% [markdown]
# # $M$

# %%
df_in = pd.DataFrame(sorted(list(set(namq_10_gdp.ID))), columns=["ID"])

###########################################################################################

# Chain linked volumes, percentage change compared to same period in previous year
var = "CLV_PCH_SM"
selec = namq_10_gdp[(namq_10_gdp.NA_ITEM=="P7")&(namq_10_gdp.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", "M"]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

# Cd
selec = namq_10_fcs[(namq_10_fcs.NA_ITEM=="P311_S14")&(namq_10_fcs.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", "Cd"]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

# Cnd
selec = namq_10_fcs[(namq_10_fcs.NA_ITEM=="P312N_S14")&(namq_10_fcs.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", "Cnd"]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

# G
selec = namq_10_gdp[(namq_10_gdp.NA_ITEM=="P3_S13")&(namq_10_gdp.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", "G"]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

# Igfcf
selec = namq_10_gdp[(namq_10_gdp.NA_ITEM=="P51G")&(namq_10_gdp.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", "Igfcf"]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

# Economic sentiment indicator
var = "BS-ESI-I"
selec = ei_bssi_m_r2[ei_bssi_m_r2.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

# Real Effective Exchange Rate (deflator consumer price indices - 42 trading partners)
var = "REER42CPI"
selec = ei_mfef_m[ei_mfef_m.INDIC==var][["ID", "Value"]]; selec.columns = ["ID", var]
df_in = pd.merge(df_in, selec, on='ID', how="inner")


#############################################

# Chain linked volumes, percentage change compared to same period in previous year
var = "CLV_PCH_SM"
selec = namq_10_gdp_lag[(namq_10_gdp_lag.NA_ITEM=="P7")&(namq_10_gdp.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", "M"+"_qoq"]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

# Cd
selec = namq_10_fcs_lag[(namq_10_fcs_lag.NA_ITEM=="P311_S14")&(namq_10_fcs.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", "Cd"+"_qoq"]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

# Cnd
selec = namq_10_fcs_lag[(namq_10_fcs_lag.NA_ITEM=="P312N_S14")&(namq_10_fcs.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", "Cnd"+"_qoq"]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

# G
selec = namq_10_gdp_lag[(namq_10_gdp_lag.NA_ITEM=="P3_S13")&(namq_10_gdp.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", "G"+"_qoq"]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

# Igfcf
selec = namq_10_gdp_lag[(namq_10_gdp_lag.NA_ITEM=="P51G")&(namq_10_gdp.UNIT==var)][["ID", "Value"]]; selec.columns = ["ID", "Igfcf"+"_qoq"]
df_in = pd.merge(df_in, selec, on='ID', how="inner")

###########################################################################################

# Dummies
countries = set(namq_10_gdp.GEO); countries.remove('PT')
for country in sorted(list(countries)):
    df_in[country] = (df_in.ID.str[-2:] == country).astype(int)

M = df_in.copy().set_index("ID")
M = M.loc[:, (M != 0).any(axis=0)].copy()
del var, selec, df_in

###########################################################################################

# Save
M.to_csv("./M.csv")

###########################################################################################

# Regression
X = sm.add_constant(M.loc[:, M.columns != "M"].copy())
y = M.loc[:, "M"].copy()
results = sm.OLS(y, X).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      M   R-squared:                       0.737
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     145.9
# Date:                Wed, 14 Nov 2018   Prob (F-statistic):               0.00
# Time:                        03:28:17   Log-Likelihood:                -4934.1
# No. Observations:                1701   AIC:                             9934.
# Df Residuals:                    1668   BIC:                         1.011e+04
# Df Model:                          32
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -12.3136      2.343     -5.255      0.000     -16.909      -7.718
# Cd             0.1046      0.018      5.836      0.000       0.069       0.140
# Cnd            0.5560      0.073      7.649      0.000       0.413       0.699
# G             -0.0141      0.053     -0.268      0.789      -0.118       0.089
# Igfcf          0.2094      0.014     15.109      0.000       0.182       0.237
# BS-ESI-I       0.1690      0.015     11.313      0.000       0.140       0.198
# REER42CPI     -0.0322      0.019     -1.717      0.086      -0.069       0.005
# M_qoq          0.6090      0.018     33.263      0.000       0.573       0.645
# Cd_qoq        -0.0257      0.019     -1.387      0.166      -0.062       0.011
# Cnd_qoq       -0.5073      0.072     -7.064      0.000      -0.648      -0.366
# G_qoq         -0.1268      0.046     -2.735      0.006      -0.218      -0.036
# Igfcf_qoq     -0.1726      0.014    -12.316      0.000      -0.200      -0.145
# AT            -0.1391      0.715     -0.195      0.846      -1.541       1.263
# BE            -0.2274      0.715     -0.318      0.750      -1.629       1.174
# BG            -0.0777      0.740     -0.105      0.916      -1.529       1.373
# CZ             0.3976      0.741      0.537      0.592      -1.056       1.851
# DE             0.2257      0.715      0.316      0.752      -1.177       1.628
# DK            -0.1508      0.715     -0.211      0.833      -1.554       1.252
# EE             0.3302      0.718      0.460      0.645      -1.077       1.738
# EL            -0.3100      0.717     -0.432      0.666      -1.717       1.097
# ES            -0.1521      0.724     -0.210      0.834      -1.572       1.268
# FI            -0.2773      0.715     -0.388      0.698      -1.680       1.126
# FR            -0.4325      0.712     -0.608      0.544      -1.829       0.964
# IT            -0.6696      0.715     -0.936      0.349      -2.073       0.733
# LT             0.3883      0.726      0.535      0.593      -1.035       1.811
# LU             1.2971      0.723      1.793      0.073      -0.121       2.716
# LV            -0.7811      0.728     -1.073      0.284      -2.209       0.647
# MT            -0.1786      0.762     -0.234      0.815      -1.674       1.317
# NL             0.2681      0.717      0.374      0.709      -1.138       1.674
# PL             1.1085      0.725      1.529      0.126      -0.313       2.530
# SE            -0.8596      0.718     -1.197      0.231      -2.267       0.548
# SI             0.2611      0.714      0.366      0.715      -1.139       1.661
# UK            -0.0375      0.770     -0.049      0.961      -1.548       1.472
# ==============================================================================
# Omnibus:                      151.345   Durbin-Watson:                   1.777
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              822.620
# Skew:                           0.203   Prob(JB):                    2.35e-179
# Kurtosis:                       6.383   Cond. No.                     3.45e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # Prepare to $\textbf{R}$

# %%
# namq_10_gdp
selec = namq_10_gdp[(namq_10_gdp.GEO == "PT") & (namq_10_gdp.UNIT == "CLV10_MEUR")]
for item in list(set(selec.NA_ITEM)):
    selec[selec.NA_ITEM==item][["TIME", "Value"]].to_csv("R/"+item+".csv", index=False)
##

# namq_10_fcs

# %%
# !sed -i "s/://g" ./data/ext_tec03_1_Data.csv

# %%
ext_tec03 = pd.read_csv("./data/ext_tec03_1_Data.csv"); ext_tec03.Value = ext_tec03.Value.replace(regex=r'[,]+', value='').astype(np.float)

# %%
XXX_source = ext_tec03[(ext_tec03.TIME==2016)& (ext_tec03.STK_FLOW=="EXP")]

# %%
XXX_source
# Out:
#       TIME GEO GEO_LABEL     UNIT     UNIT_LABEL STK_FLOW STK_FLOW_LABEL  \
# 78    2016  BE   Belgium  THS_EUR  Thousand euro      EXP        Exports
# 79    2016  BE   Belgium  THS_EUR  Thousand euro      EXP        Exports
# 80    2016  BE   Belgium  THS_EUR  Thousand euro      EXP        Exports
# 81    2016  BE   Belgium  THS_EUR  Thousand euro      EXP        Exports
# 82    2016  BE   Belgium  THS_EUR  Thousand euro      EXP        Exports
# 83    2016  BE   Belgium  THS_EUR  Thousand euro      EXP        Exports
# 84    2016  BE   Belgium  THS_EUR  Thousand euro      EXP        Exports
# 85    2016  BE   Belgium  THS_EUR  Thousand euro      EXP        Exports
# 86    2016  BE   Belgium  THS_EUR  Thousand euro      EXP        Exports
# 87    2016  BE   Belgium  THS_EUR  Thousand euro      EXP        Exports
# ...    ...  ..       ...      ...            ...      ...            ...
# 4670  2016  NO    Norway  THS_EUR  Thousand euro      EXP        Exports
# 4671  2016  NO    Norway  THS_EUR  Thousand euro      EXP        Exports
# 4672  2016  NO    Norway  THS_EUR  Thousand euro      EXP        Exports
# 4673  2016  NO    Norway  THS_EUR  Thousand euro      EXP        Exports
# 4674  2016  NO    Norway  THS_EUR  Thousand euro      EXP        Exports
# 4675  2016  NO    Norway  THS_EUR  Thousand euro      EXP        Exports
# 4676  2016  NO    Norway  THS_EUR  Thousand euro      EXP        Exports
# 4677  2016  NO    Norway  THS_EUR  Thousand euro      EXP        Exports
# 4678  2016  NO    Norway  THS_EUR  Thousand euro      EXP        Exports
# 4679  2016  NO    Norway  THS_EUR  Thousand euro      EXP        Exports
#
#      NACE_R2                NACE_R2_LABEL  PARTNER  \
# 78     TOTAL  Total - all NACE activities       BE
# 79     TOTAL  Total - all NACE activities       BG
# 80     TOTAL  Total - all NACE activities       CZ
# 81     TOTAL  Total - all NACE activities       DK
# 82     TOTAL  Total - all NACE activities       DE
# 83     TOTAL  Total - all NACE activities       EE
# 84     TOTAL  Total - all NACE activities       IE
# 85     TOTAL  Total - all NACE activities       EL
# 86     TOTAL  Total - all NACE activities       ES
# 87     TOTAL  Total - all NACE activities       FR
# ...      ...                          ...      ...
# 4670   TOTAL  Total - all NACE activities       VN
# 4671   TOTAL  Total - all NACE activities       IL
# 4672   TOTAL  Total - all NACE activities       QA
# 4673   TOTAL  Total - all NACE activities       SA
# 4674   TOTAL  Total - all NACE activities       AE
# 4675   TOTAL  Total - all NACE activities  ASI_NME
# 4676   TOTAL  Total - all NACE activities  ASI_OTH
# 4677   TOTAL  Total - all NACE activities  OCE_PLR
# 4678   TOTAL  Total - all NACE activities       AU
# 4679   TOTAL  Total - all NACE activities    WORLD
#
#                                                                 PARTNER_LABEL  \
# 78                                                                    Belgium
# 79                                                                   Bulgaria
# 80                                                                    Czechia
# 81                                                                    Denmark
# 82                           Germany (until 1990 former territory of the FRG)
# 83                                                                    Estonia
# 84                                                                    Ireland
# 85                                                                     Greece
# 86                                                                      Spain
# 87                                                                     France
# ...                                                                       ...
# 4670                                                                  Vietnam
# 4671                                                                   Israel
# 4672                                                                    Qatar
# 4673                                                             Saudi Arabia
# 4674                                                     United Arab Emirates
# 4675  Near and Middle East Asia (aggregate changing according to the context)
# 4676      Other Asian countries (aggregate changing according to the context)
# 4677                                       Oceania and southern polar regions
# 4678                                                                Australia
# 4679                                               All countries of the world
#
#             Value
# 78            NaN
# 79      723038.76
# 80     3062748.32
# 81     2730865.47
# 82    58529869.07
# 83      329362.35
# 84     1943375.20
# 85     1573867.91
# 86     9334137.83
# 87    54350358.47
# ...           ...
# 4670          NaN
# 4671          NaN
# 4672          NaN
# 4673          NaN
# 4674          NaN
# 4675          NaN
# 4676          NaN
# 4677          NaN
# 4678          NaN
# 4679          NaN
#
# [2340 rows x 12 columns]

# %%
XXX_countries = sorted(list(set(ext_tec03.GEO.values)))
XXX_matrix = pd.DataFrame(index=XXX_countries, columns=XXX_countries)
for ind, row in XXX_source.iterrows():
    if row.GEO == row.PARTNER:
        XXX_matrix.loc[row.GEO][row.PARTNER]=0
    else:
        XXX_matrix.loc[row.GEO][row.PARTNER]=row.Value#/np.sum(XXX_source[XXX_source.GEO==row.GEO].Value)
XXX_matrix = XXX_matrix.dropna()

# %%
np.sum(XXX_matrix.iloc[1,:])
# Out:
# 256238001.25999993

# %%
XXX_matrix
# Out:
#              AT           BE           BG           CY           CZ  \
# AT            0  1.67695e+06       660019      51824.9  4.66456e+06
# BE  3.52846e+06            0       723039       191600  3.06275e+06
# BG       452372       639279            0      80552.9       395038
# CZ  4.28736e+06  2.15312e+06       546755      81142.2            0
# DE  5.04384e+07  3.26308e+07  2.94653e+06       444362  3.18052e+07
# DK       623986  1.54125e+06       111439      39637.7       794996
# EE      40254.6       198182      23963.5      15126.4      59468.1
# EL       199590       345339  1.25256e+06  1.52391e+06       203289
# ES  2.13769e+06  7.58934e+06       453188       227166  2.07482e+06
# FI       319513  1.70025e+06      67771.2      13648.9       248461
# ..          ...          ...          ...          ...          ...
# LT      94067.3       260431      49946.8      10217.1       206416
# LV      41442.5       120517      39835.6      24355.5       138668
# NL  4.11445e+06  2.99792e+07       572515       243216  3.80146e+06
# PL  2.36512e+06   3.0115e+06       898145       158420  9.69794e+06
# PT       290586  1.19352e+06      73059.1      36309.6       291322
# RO  1.31267e+06  1.06411e+06  1.71353e+06      60475.7  1.48634e+06
# SE   1.0141e+06  5.80286e+06       119119      28230.6  1.00421e+06
# SI  1.81052e+06       248213       197309      23042.6       516751
# SK  2.72233e+06       962384       343573      63621.3  7.53323e+06
# UK  2.13786e+06  1.30997e+07       577540       367105  2.50816e+06
#
#              DE           DK           EE           EL           ES  \
# AT  3.97229e+07       725452       153603       420755  2.42489e+06
# DK       256394  1.01778e+07        87142       215377  5.79585e+06
# EE      78602.5  2.01993e+06      8688.23      20113.2       258031
# EL       750290       182698       210477      78949.4  1.06464e+06
# ES  1.61383e+06  2.04883e+06       453998       854727  1.88159e+07
# FI       134415  5.34347e+06      74391.4       100875  2.42981e+06
# ..          ...          ...          ...          ...          ...
# LT      67281.3       902948      29854.3      81146.9       866663
# LV      18045.5       602021      9717.05      47184.7       562267
# NL  1.80287e+06   6.3399e+06       569431   1.0618e+06  3.13588e+07
# PL  2.65696e+06    4.151e+06       519998  3.88724e+06  9.58362e+06
# PT       386054       465987      28999.3       224327  3.50085e+06
# RO            0       529136       299921       983937  2.40456e+06
# SE       294818            0       124040       284842  7.42844e+06
# SI       358553       268272            0       413177       480900
# SK  1.38261e+06       917636       421306            0   3.7035e+06
# UK  1.20357e+06  5.36137e+06       280970       609915            0
#
# [24 rows x 30 columns]

# %%
XXX_matrix.sum(axis=1)
# Out:
# AT    9.437352e+07
# BE    2.562380e+08
# BG    1.505221e+07
# CZ    8.458357e+07
# DE    5.645623e+08
# DK    6.103506e+07
# EE    8.529834e+06
# EL    1.407019e+07
# ES    1.576004e+08
# FI    3.116099e+07
#           ...
# LT    1.278070e+07
# LV    7.532603e+06
# NL    2.415852e+08
# PL    1.171022e+08
# PT    3.632569e+07
# RO    4.178818e+07
# SE    8.330180e+07
# SI    1.704964e+07
# SK    5.224070e+07
# UK    1.675357e+08
# Length: 24, dtype: float64

# %%
XXX_matrix.iloc[0,1]/XXX_matrix.sum(axis=1)[0]
# Out:
# 0.017769324319458508

# %%
XXX_matrix.divide(XXX_matrix.sum(axis=1), axis=0)
# Out:
#             AT         BE          BG           CY          CZ         DE  \
# AT           0  0.0177693  0.00699368  0.000549147   0.0494265   0.420912
# BE   0.0137702          0  0.00282175  0.000747742   0.0119527    0.22842
# BG   0.0300536  0.0424708           0   0.00535157   0.0262445   0.203395
# CZ   0.0506878  0.0254555  0.00646408  0.000959314           0   0.384203
# DE   0.0893407  0.0577984  0.00521915  0.000787092    0.056336          0
# DK   0.0102234  0.0252519  0.00182582  0.000649425   0.0130252   0.237417
# EE  0.00471928   0.023234  0.00280937   0.00177336  0.00697177  0.0733548
# EL   0.0141853   0.024544   0.0890226     0.108308   0.0144482   0.137163
# ES    0.013564  0.0481556  0.00287555   0.00144141   0.0131651    0.17828
# FI   0.0102536  0.0545633  0.00217487  0.000438011  0.00797347   0.214036
# ..         ...        ...         ...          ...         ...        ...
# LT   0.0073601  0.0203769  0.00390799  0.000799415   0.0161506   0.119197
# LV  0.00550175  0.0159994  0.00528843   0.00323335   0.0184091  0.0950753
# NL   0.0170311   0.124094  0.00236983   0.00100675   0.0157355   0.338468
# PL   0.0201971  0.0257168  0.00766975   0.00135284    0.082816   0.325138
# PT  0.00799946   0.032856  0.00201122  0.000999558  0.00801971   0.159535
# RO   0.0314126  0.0254644   0.0410052    0.0014472   0.0355684    0.28821
# SE   0.0121738  0.0696607  0.00142996  0.000338895   0.0120551   0.154998
